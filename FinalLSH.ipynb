# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_csv('movies_with_test.csv')
# Out:
# C:\Users\minht\AppData\Local\Temp\ipykernel_19172\2877273640.py:1: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('movies_with_test.csv')

# %%
df.shape
# Out:
# (930739, 2)

# %%
def create_shingles(text, min_length=1, max_length=None):
  tags = [tag.strip() for tag in text.split(',')]  # Tách các tag riêng biệt

  all_shingles = set()
  for tag in tags:
      words = tag.split()  # Tách tag thành các từ
      if max_length is None:
          max_length = max(len(word) for word in words)
      for word in words:
          for i in range(min_length, min(max_length, len(word)) + 1):
              all_shingles.add(word[:i])
  return all_shingles

df['shingles'] = df['genres'].astype(str).apply(create_shingles)

# %%
df['shingles']
# Out:
# 0                         {Comed, Come, Co, Comedy, C, Com}
# 1                                 {D, Dram, Dra, Dr, Drama}
# 2         {A, Adul, Come, Comed, Ad, Co, C, Com, Adu, Ad...
# 3         {Ani, Anim, Sh, Anima, S, Animat, F, Animati, ...
# 4                                 {D, Dram, Dra, Dr, Drama}
#                                 ...
# 930734                                         {na, n, nan}
# 930735                                         {na, n, nan}
# 930736                                         {na, n, nan}
# 930737                                         {na, n, nan}
# 930738                                         {na, n, nan}
# Name: shingles, Length: 930739, dtype: object

# %%
def create_hash_functions(num_hash_functions, max_val):
    hash_functions = []
    for _ in range(num_hash_functions):
        a = random.randint(1, max_val)
        b = random.randint(0, max_val)
        hash_functions.append(lambda x, a=a, b=b: (a * x + b) % max_val)
    return a,b

def minhash_signature(shingles, hash_functions):
    signature = [float('inf')] * len(hash_functions) 
    for shingle in shingles:
        shingle_hash = hash(shingle)
        for i, hash_func in enumerate(hash_functions):
            signature[i] = min(signature[i], hash_func(shingle_hash))
    return signature

all_shingles = set()
for shingles_list in df['shingles']:
    all_shingles.update(shingles_list)

print (create_hash_functions(10, 11))
# Create 10 hash functions
# hash_functions = create_hash_functions(10, len(all_shingles))

# # Apply minhash_signature to each row in the `shingles` column
# df['minhash_signature'] = df['shingles'].apply(lambda x: minhash_signature(x, hash_functions))
# Out:
# (11, 0)

# %%
df.head(20)
# Out:
#                  originalTitle                   genres
# 0               Episode #1.106                   Comedy  \
# 1               Fagr Yom gedid                    Drama
# 2                        Denim             Adult,Comedy
# 3              The Millionaire   Animation,Family,Short
# 4         The Pigman's Protege                    Drama
# 5              Der Hausmeister                    Adult
# 6                 Episode #1.1                   Comedy
# 7            The Ixtafa Affair  Action,Adventure,Sci-Fi
# 8    Flag Wars Community Forum              Documentary
# 9                 Episode #1.4                    Drama
# 10           Ten Cents a Dance                   Comedy
# 11              Episode #1.135                   Family
# 12    A kétségbeesés méltósága              Documentary
# 13                      Karino                   Family
# 14               Episode #1.23     Drama,Family,Romance
# 15            The Sleep Walker             Comedy,Drama
# 16                 Bad Fortune       Action,Crime,Drama
# 17              Synthetic Love  Action,Adventure,Horror
# 18  Episode dated 24 June 2004           News,Talk-Show
# 19  Episode dated 7 March 1961           Family,Musical
#
#                                              shingles
# 0                   {Comed, Come, Co, Comedy, C, Com}  \
# 1                           {D, Dram, Dra, Dr, Drama}
# 2   {A, Adul, Come, Comed, Ad, Co, C, Com, Adu, Ad...
# 3   {Ani, Anim, Sh, Anima, S, Animat, F, Animati, ...
# 4                           {D, Dram, Dra, Dr, Drama}
# 5                           {A, Adul, Ad, Adu, Adult}
# 6                   {Comed, Come, Co, Comedy, C, Com}
# 7   {Action, Sci, A, Sci-Fi, Sci-, Ac, Acti, S, Sc...
# 8   {Documentar, Docume, Docu, Do, D, Doc, Documen...
# 9                           {D, Dram, Dra, Dr, Drama}
# 10                  {Comed, Come, Co, Comedy, C, Com}
# 11                  {Fami, Fam, Fa, Famil, F, Family}
# 12  {Documentar, Docume, Docu, Do, D, Doc, Documen...
# 13                  {Fami, Fam, Fa, Famil, F, Family}
# 14  {Fami, Ro, D, Fa, Fam, Famil, Rom, Roma, Roman...
# 15  {Comed, Come, D, Co, Comedy, C, Com, Dra, Dram...
# 16  {Action, A, Crime, Ac, Acti, D, Cri, C, Dr, Dr...
# 17  {Action, A, Ho, Ac, Acti, Ad, Horr, Adve, H, A...
# 18               {Tal, New, N, Ta, Ne, Talk, T, News}
# 19  {Mus, Fami, Fam, Fa, Famil, M, Mu, Musica, Mus...
#
#                           minhash_signature
# 0    [21, 17, 13, 30, 2, 37, 31, 1, 73, 29]
# 1   [41, 27, 91, 16, 90, 1, 27, 26, 73, 27]
# 2      [29, 17, 13, 3, 2, 2, 31, 1, 73, 50]
# 3           [5, 9, 1, 0, 2, 0, 3, 5, 73, 4]
# 4   [41, 27, 91, 16, 90, 1, 27, 26, 73, 27]
# 5     [53, 33, 69, 3, 34, 2, 31, 9, 73, 62]
# 6    [21, 17, 13, 30, 2, 37, 31, 1, 73, 29]
# 7        [5, 17, 13, 0, 10, 2, 3, 1, 73, 1]
# 8          [5, 7, 3, 6, 6, 1, 5, 2, 73, 12]
# 9   [41, 27, 91, 16, 90, 1, 27, 26, 73, 27]
# 10   [21, 17, 13, 30, 2, 37, 31, 1, 73, 29]
# 11     [5, 25, 27, 0, 66, 63, 3, 5, 73, 11]
# 12         [5, 7, 3, 6, 6, 1, 5, 2, 73, 12]
# 13     [5, 25, 27, 0, 66, 63, 3, 5, 73, 11]
# 14       [1, 3, 27, 0, 26, 1, 3, 5, 73, 10]
# 15    [21, 17, 13, 16, 2, 1, 27, 1, 73, 27]
# 16         [5, 3, 7, 0, 34, 1, 3, 9, 73, 4]
# 17         [5, 9, 11, 0, 2, 2, 3, 1, 73, 4]
# 18     [25, 9, 37, 1, 6, 11, 19, 8, 73, 28]
# 19     [5, 25, 27, 0, 18, 63, 3, 5, 73, 11]

# %%
class LSH:
    def __init__(self, num_bands, num_rows_per_band):
        self.num_bands = num_bands
        self.num_rows_per_band = num_rows_per_band
        self.buckets = {}  # Lưu trữ các nhóm (bucket)

    def hash_function(self, signature, band_index):
        """
        Hàm băm đơn giản để ánh xạ một phần của chữ ký MinHash vào một nhóm.
        """
        start_row = band_index * self.num_rows_per_band
        end_row = start_row + self.num_rows_per_band
        band_signature = tuple(signature[start_row:end_row])
        return hash(band_signature)

    def insert(self, key, signature):
        """
        Chèn một mục (key) và chữ ký MinHash của nó vào các nhóm LSH.
        """
        for band_index in range(self.num_bands):
            bucket_id = self.hash_function(signature, band_index)
            if bucket_id not in self.buckets:
                self.buckets[bucket_id] = []
            self.buckets[bucket_id].append(key)

    def movie_similar(self, query_signature):
        """
        Truy vấn các mục có khả năng tương tự dựa trên chữ ký MinHash của truy vấn.
        """
        candidates = set()
        for band_index in range(self.num_bands):
            bucket_id = self.hash_function(query_signature, band_index)
            if bucket_id in self.buckets:
                candidates.update(self.buckets[bucket_id])
        return candidates
    def movie_query(self, tag_query):
        pass

# %%
# Định nghĩa hàm tính độ tương đồng Jaccard
def jaccard_similarity(set1, set2):
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union if union != 0 else 0

# %%
# Khởi tạo LSH với số lượng bands và số hàng mỗi band
lsh = LSH(num_bands=5, num_rows_per_band=2)

# Chèn các bộ phim vào LSH
for index, row in df.iterrows():
    lsh.insert(row['originalTitle'], row['minhash_signature'])

# Truy vấn phim tương tự
query_movie = 'The Millionaire'
query_signature = df[df['originalTitle'] == query_movie]['minhash_signature'].iloc[0]
candidate_movies = lsh.movie_similar(query_signature)

# Kiểm tra danh sách phim ứng viên
print("Danh sách phim ứng viên:", candidate_movies)

# Tính độ tương đồng Jaccard cho các phim ứng viên
similarities = []
for candidate_movie in candidate_movies:
    if candidate_movie in df['originalTitle'].values:
        candidate_signature = df[df['originalTitle'] == candidate_movie]['minhash_signature'].iloc[0]
        raw_similarity = jaccard_similarity(set(query_signature), set(candidate_signature))
        # Đảm bảo rằng giá trị của len(hash_functions) không gây chia cho 0 hoặc gây lỗi
        normalized_similarity = raw_similarity / len(hash_functions)
        print(f"Movie: {candidate_movie}, Raw Similarity: {raw_similarity}, Normalized Similarity: {normalized_similarity}")
        similarities.append((candidate_movie, normalized_similarity))
    else:
        print(f"Chữ ký MinHash không tìm thấy cho phim: {candidate_movie}")
# Out:
# Danh sách phim ứng viên: {'Episode #1.135', 'À malin, malin et demi', 'Alas sobre El Chaco', "Katie's Secret", 'Episode #1.23', 'The Chinese Dolls', 'Mirovoy paren', 'Sinfonia Amazônica', 'Botas Texanas y balas salvajes', 'Sadaf va Morvarid', 'Big Business', 'One Piece: Oounabara ni hirake! Dekkai dekkai chichi no yume!', 'The Pythoness', 'Chapter 15', 'Episode dated 7 March 1961', 'Super Dave: Daredevil for Hire', 'Priyasakhi', 'A Fox in a Fix', 'The Brothers Gruff', 'Wood', 'Danger Zone', 'Tobunda ôzora he', 'Niji no ike no jigoku janguru', 'Lili', 'The Rain in Spain', 'Bad Fortune', 'The Millionaire', 'Return of the Seven', 'Karino', 'Synthetic Love', '100 eyes see their destiny'}
# Movie: Episode #1.135, Raw Similarity: 0.3076923076923077, Normalized Similarity: 0.03076923076923077
# Movie: À malin, malin et demi, Raw Similarity: 0.2857142857142857, Normalized Similarity: 0.02857142857142857
# Movie: Alas sobre El Chaco, Raw Similarity: 0.5454545454545454, Normalized Similarity: 0.05454545454545454
# Movie: Katie's Secret, Raw Similarity: 0.7777777777777778, Normalized Similarity: 0.07777777777777778
# Movie: Episode #1.23, Raw Similarity: 0.45454545454545453, Normalized Similarity: 0.045454545454545456
# Movie: The Chinese Dolls, Raw Similarity: 0.7, Normalized Similarity: 0.06999999999999999
# Movie: Mirovoy paren, Raw Similarity: 0.6, Normalized Similarity: 0.06
# Movie: Sinfonia Amazônica, Raw Similarity: 0.6, Normalized Similarity: 0.06
# Movie: Botas Texanas y balas salvajes, Raw Similarity: 0.6363636363636364, Normalized Similarity: 0.06363636363636363
# Movie: Sadaf va Morvarid, Raw Similarity: 0.4166666666666667, Normalized Similarity: 0.04166666666666667
# Movie: Big Business, Raw Similarity: 0.3076923076923077, Normalized Similarity: 0.03076923076923077
# Movie: One Piece: Oounabara ni hirake! Dekkai dekkai chichi no yume!, Raw Similarity: 0.8, Normalized Similarity: 0.08
# Movie: The Pythoness, Raw Similarity: 0.4166666666666667, Normalized Similarity: 0.04166666666666667
# Movie: Chapter 15, Raw Similarity: 0.7, Normalized Similarity: 0.06999999999999999
# Movie: Episode dated 7 March 1961, Raw Similarity: 0.3076923076923077, Normalized Similarity: 0.03076923076923077
# Movie: Super Dave: Daredevil for Hire, Raw Similarity: 0.8888888888888888, Normalized Similarity: 0.08888888888888888
# Movie: Priyasakhi, Raw Similarity: 0.45454545454545453, Normalized Similarity: 0.045454545454545456
# Movie: A Fox in a Fix, Raw Similarity: 0.8888888888888888, Normalized Similarity: 0.08888888888888888
# Movie: The Brothers Gruff, Raw Similarity: 0.7777777777777778, Normalized Similarity: 0.07777777777777778
# Movie: Wood, Raw Similarity: 0.5454545454545454, Normalized Similarity: 0.05454545454545454
# Movie: Danger Zone, Raw Similarity: 0.6363636363636364, Normalized Similarity: 0.06363636363636363
# Movie: Tobunda ôzora he, Raw Similarity: 0.8888888888888888, Normalized Similarity: 0.08888888888888888
# Movie: Niji no ike no jigoku janguru, Raw Similarity: 0.8888888888888888, Normalized Similarity: 0.08888888888888888
# Movie: Lili, Raw Similarity: 0.5454545454545454, Normalized Similarity: 0.05454545454545454
# Movie: The Rain in Spain, Raw Similarity: 0.3076923076923077, Normalized Similarity: 0.03076923076923077
# Movie: Bad Fortune, Raw Similarity: 0.7, Normalized Similarity: 0.06999999999999999
# Movie: The Millionaire, Raw Similarity: 1.0, Normalized Similarity: 0.1
# Movie: Return of the Seven, Raw Similarity: 0.5, Normalized Similarity: 0.05
# Movie: Karino, Raw Similarity: 0.3076923076923077, Normalized Similarity: 0.03076923076923077
# Movie: Synthetic Love, Raw Similarity: 0.8888888888888888, Normalized Similarity: 0.08888888888888888
# Movie: 100 eyes see their destiny, Raw Similarity: 0.7, Normalized Similarity: 0.06999999999999999

# %%
# Lọc phim dựa trên ngưỡng độ tương đồng
threshold = 0.05
filtered_movies = [(movie, sim) for movie, sim in similarities if sim > threshold]

# In kết quả phim tương tự
for movie, similarity in filtered_movies:
    if movie != query_movie:  # Loại trừ phim truy vấn
        print(f"Movie: {movie}, Jaccard Similarity: {similarity}")

print("Danh sách phim lọc:", filtered_movies)
# Out:
# Movie: Alas sobre El Chaco, Jaccard Similarity: 0.05454545454545454
# Movie: Katie's Secret, Jaccard Similarity: 0.07777777777777778
# Movie: The Chinese Dolls, Jaccard Similarity: 0.06999999999999999
# Movie: Mirovoy paren, Jaccard Similarity: 0.06
# Movie: Sinfonia Amazônica, Jaccard Similarity: 0.06
# Movie: Botas Texanas y balas salvajes, Jaccard Similarity: 0.06363636363636363
# Movie: One Piece: Oounabara ni hirake! Dekkai dekkai chichi no yume!, Jaccard Similarity: 0.08
# Movie: Chapter 15, Jaccard Similarity: 0.06999999999999999
# Movie: Super Dave: Daredevil for Hire, Jaccard Similarity: 0.08888888888888888
# Movie: A Fox in a Fix, Jaccard Similarity: 0.08888888888888888
# Movie: The Brothers Gruff, Jaccard Similarity: 0.07777777777777778
# Movie: Wood, Jaccard Similarity: 0.05454545454545454
# Movie: Danger Zone, Jaccard Similarity: 0.06363636363636363
# Movie: Tobunda ôzora he, Jaccard Similarity: 0.08888888888888888
# Movie: Niji no ike no jigoku janguru, Jaccard Similarity: 0.08888888888888888
# Movie: Lili, Jaccard Similarity: 0.05454545454545454
# Movie: Bad Fortune, Jaccard Similarity: 0.06999999999999999
# Movie: Synthetic Love, Jaccard Similarity: 0.08888888888888888
# Movie: 100 eyes see their destiny, Jaccard Similarity: 0.06999999999999999
# Danh sách phim lọc: [('Alas sobre El Chaco', 0.05454545454545454), ("Katie's Secret", 0.07777777777777778), ('The Chinese Dolls', 0.06999999999999999), ('Mirovoy paren', 0.06), ('Sinfonia Amazônica', 0.06), ('Botas Texanas y balas salvajes', 0.06363636363636363), ('One Piece: Oounabara ni hirake! Dekkai dekkai chichi no yume!', 0.08), ('Chapter 15', 0.06999999999999999), ('Super Dave: Daredevil for Hire', 0.08888888888888888), ('A Fox in a Fix', 0.08888888888888888), ('The Brothers Gruff', 0.07777777777777778), ('Wood', 0.05454545454545454), ('Danger Zone', 0.06363636363636363), ('Tobunda ôzora he', 0.08888888888888888), ('Niji no ike no jigoku janguru', 0.08888888888888888), ('Lili', 0.05454545454545454), ('Bad Fortune', 0.06999999999999999), ('The Millionaire', 0.1), ('Synthetic Love', 0.08888888888888888), ('100 eyes see their destiny', 0.06999999999999999)]
