# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
data = pd.read_csv("movies_metadata.csv")
data.head(5)
# Out:
# C:\Users\minht\AppData\Local\Temp\ipykernel_17244\3867273793.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(movies_metadata)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
# Load data into a DataFrame
df = pd.DataFrame(data)
# Function to convert the JSON-like string to a comma-separated string of genre names
def convert_genres(genre_str):
    try:
        # Parse the JSON-like string
        genre_list = json.loads(genre_str.replace("'", "\""))
        # Extract the genre names and join them with commas
        return ', '.join(genre['name'] for genre in genre_list)
    except (json.JSONDecodeError, TypeError):
        return None  # Return None if parsing fails

# Apply the function to the genres column
df['tag'] = df['genres'].apply(convert_genres)

# Display the DataFrame
out_df = df[['title', 'tag']]
print(df[['title', 'tag']].head())
# Out:
#                          title                         tag
# 0                    Toy Story   Animation, Comedy, Family
# 1                      Jumanji  Adventure, Fantasy, Family
# 2             Grumpier Old Men             Romance, Comedy
# 3            Waiting to Exhale      Comedy, Drama, Romance
# 4  Father of the Bride Part II                      Comedy

# %%
# Save the DataFrame to a new CSV file
out_df.to_csv('C:/Users/minht/OneDrive/Documents/HCMUS/Nam4/Paralel/movies_with_genres.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Save the DataFrame to a new CSV file
# ----> 2 out_df.to_csv('C:/Users/minht/OneDrive/Documents/HCMUS/Nam4/Paralel/movies_with_genres.csv', index=False)
#
# File c:\Users\minht\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...
